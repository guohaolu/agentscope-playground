# %% [markdown]
# # 1.1 安装与环境
#
# - **对应文档**: [quickstart_installation](https://doc.agentscope.io/tutorial/quickstart_installation.html)
# - **本讲目标**: 安装 AgentScope，验证环境，了解可选依赖。
# - **前置知识**: Python 3.10+，pip。

# %% [markdown]
# ## 从 PyPI 安装

# %%
# 基础安装（本 notebook 仅做导入验证时可只装 agentscope）
# 若需完整模型 API 与工具，使用: pip install "agentscope[full]"
# !pip install agentscope

# %% [markdown]
# ## 验证安装

# %%
import agentscope

print(f"AgentScope 版本: {agentscope.__version__}")
# Out:
# AgentScope 版本: 1.0.16

# %% [markdown]
# ## 可选依赖
#
# - `agentscope[full]`: 模型 API、工具等完整依赖（Windows: `pip install agentscope[full]`，Mac/Linux 需转义方括号）
# - `agentscope[dev]`: 开发与文档工具
