# %% [markdown]
# # 6.5 Features - Evaluation / OpenJudge
#
# - **对应文档**: [task_eval](https://doc.agentscope.io/tutorial/task_eval.html), [task_eval_openjudge](https://doc.agentscope.io/tutorial/task_eval_openjudge.html)
# - **本讲目标**: 理解 Agent 评估流程与 OpenJudge 集成。
# - **前置知识**: 02_react_agent。

# %%
# 在此按 doc 编写 Evaluation / OpenJudge 示例
# 参考 https://doc.agentscope.io/tutorial/task_eval.html
print("请参考 task_eval / task_eval_openjudge 文档完成评估示例代码")
