# %% [markdown]
# # 3.4 Model and Context - Token 与上下文长度
#
# - **对应文档**: [task_token](https://doc.agentscope.io/tutorial/task_token.html)
# - **本讲目标**: 理解 token 计数、上下文窗口限制与截断策略。
# - **前置知识**: 10_task_model, 11_task_memory。

# %% [markdown]
# ## 学习要点
#
# - 如何估算或获取消息的 token 数。
# - 超出限制时的裁剪/摘要策略。

# %%
# 在此按 doc 编写 Token 与上下文示例
# 参考 https://doc.agentscope.io/tutorial/task_token.html
print("请参考 task_token 文档完成 Token 示例代码")
