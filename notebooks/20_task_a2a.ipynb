# %% [markdown]
# # 5.3 Agent - A2A Agent
#
# - **对应文档**: [task_a2a](https://doc.agentscope.io/tutorial/task_a2a.html)
# - **本讲目标**: 掌握 Agent-to-Agent 通信与 A2A 协议/接口。
# - **前置知识**: 18_task_agent。

# %%
# 在此按 doc 编写 A2A Agent 示例
# 参考 https://doc.agentscope.io/tutorial/task_a2a.html
print("请参考 task_a2a 文档完成 A2A 示例代码")
