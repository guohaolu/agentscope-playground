# %% [markdown]
# # 6.2 Features - Pipeline
#
# - **对应文档**: [task_pipeline](https://doc.agentscope.io/tutorial/task_pipeline.html)
# - **本讲目标**: 理解 Pipeline 编排多步任务与 Agent 的用法。
# - **前置知识**: 02_react_agent, Workflow 相关 notebook。

# %%
# 在此按 doc 编写 Pipeline 示例
# 参考 https://doc.agentscope.io/tutorial/task_pipeline.html
print("请参考 task_pipeline 文档完成 Pipeline 示例代码")
