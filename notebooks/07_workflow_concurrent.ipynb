# %% [markdown]
# # 2.3 Workflow - Concurrent Agents 并发
#
# - **对应文档**: [workflow_concurrent_agents](https://doc.agentscope.io/tutorial/workflow_concurrent_agents.html)
# - **本讲目标**: 理解多个 Agent 并发执行任务的方式与 API。
# - **前置知识**: 02_react_agent, asyncio 基础。

# %% [markdown]
# ## 学习要点
#
# - 使用 asyncio 或框架提供的并发原语同时调用多个 Agent。
# - 聚合并发结果用于后续流程。

# %%
# 在此按 doc 编写并发 Agent 示例
# 参考 https://doc.agentscope.io/tutorial/workflow_concurrent_agents.html
import asyncio
print("请参考 workflow_concurrent_agents 文档完成并发示例代码")

# %%
import asyncio
from datetime import datetime
from typing import Any

from agentscope.agent import AgentBase


class ExampleAgent(AgentBase):
    """用于并发执行的示例智能体。"""

    def __init__(self, name: str) -> None:
        """使用智能体名称初始化智能体。"""
        super().__init__()
        self.name = name

    async def reply(self, *args: Any, **kwargs: Any) -> None:
        """回复消息。"""
        start_time = datetime.now().strftime("%H:%M:%S.%f")[:-3]
        print(f"{self.name} 开始于 {start_time}")
        await asyncio.sleep(3)  # 模拟长时间运行的任务
        end_time = datetime.now().strftime("%H:%M:%S.%f")[:-3]
        print(f"{self.name} 结束于 {end_time}")


async def run_concurrent_agents() -> None:
    """运行并发智能体。"""
    agent1 = ExampleAgent("智能体 1")
    agent2 = ExampleAgent("智能体 2")

    await asyncio.gather(agent1(), agent2())


await run_concurrent_agents()
# Out:
# 智能体 1 开始于 14:47:09.458
# 智能体 2 开始于 14:47:09.458
# 智能体 1 结束于 14:47:12.471
# 智能体 2 结束于 14:47:12.472
