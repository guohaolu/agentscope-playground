# %% [markdown]
# # 3.3 Model and Context - Long-Term Memory 长期记忆
#
# - **对应文档**: [task_long_term_memory](https://doc.agentscope.io/tutorial/task_long_term_memory.html)
# - **本讲目标**: 掌握长期记忆的 agent_control / static_control 模式及检索与记录。
# - **前置知识**: 11_task_memory。

# %% [markdown]
# ## 学习要点
#
# - 长期记忆与短期记忆的配合。
# - 由 Agent 自主管理 vs 在 reply 前后自动读写。

# %%
# 在此按 doc 编写 Long-Term Memory 示例
# 参考 https://doc.agentscope.io/tutorial/task_long_term_memory.html
print("请参考 task_long_term_memory 文档完成长期记忆示例代码")
