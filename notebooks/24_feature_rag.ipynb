# %% [markdown]
# # 6.1 Features - RAG
#
# - **对应文档**: [task_rag](https://doc.agentscope.io/tutorial/task_rag.html)
# - **本讲目标**: 掌握 AgentScope 中 RAG（检索增强生成）的集成与用法。
# - **前置知识**: 02_react_agent, 11_task_memory。

# %%
# 在此按 doc 编写 RAG 示例
# 参考 https://doc.agentscope.io/tutorial/task_rag.html
print("请参考 task_rag 文档完成 RAG 示例代码")
