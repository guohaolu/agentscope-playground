# %% [markdown]
# # 6.4 Features - Tracing
#
# - **对应文档**: [task_tracing](https://doc.agentscope.io/tutorial/task_tracing.html)
# - **本讲目标**: 掌握调用链追踪、调试与观测方式。
# - **前置知识**: 02_react_agent。

# %%
# 在此按 doc 编写 Tracing 示例
# 参考 https://doc.agentscope.io/tutorial/task_tracing.html
print("请参考 task_tracing 文档完成 Tracing 示例代码")
