# %% [markdown]
# # 5.6 Agent - State/Session 管理
#
# - **对应文档**: [task_state](https://doc.agentscope.io/tutorial/task_state.html)
# - **本讲目标**: 掌握 state_dict/load_state_dict 与 Session 的保存与恢复。
# - **前置知识**: 04_key_concept, 18_task_agent。

# %%
# 在此按 doc 编写 State/Session 示例
# 参考 https://doc.agentscope.io/tutorial/task_state.html
print("请参考 task_state 文档完成 State/Session 示例代码")
