# %% [markdown]
# # 5.4 Agent - Middleware
#
# - **对应文档**: [task_middleware](https://doc.agentscope.io/tutorial/task_middleware.html)
# - **本讲目标**: 理解 Agent 中间件的作用与实现方式。
# - **前置知识**: 18_task_agent。

# %%
# 在此按 doc 编写 Middleware 示例
# 参考 https://doc.agentscope.io/tutorial/task_middleware.html
print("请参考 task_middleware 文档完成 Middleware 示例代码")
