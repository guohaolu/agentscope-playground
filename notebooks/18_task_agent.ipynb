# %% [markdown]
# # 5.1 Agent - 基础与扩展
#
# - **对应文档**: [task_agent](https://doc.agentscope.io/tutorial/task_agent.html)
# - **本讲目标**: 深入 AgentBase/ReActAgentBase、hooks、并行工具调用等。
# - **前置知识**: 02_react_agent, 15_task_tool。

# %%
# 在此按 doc 编写 Agent 进阶示例
# 参考 https://doc.agentscope.io/tutorial/task_agent.html
print("请参考 task_agent 文档完成 Agent 进阶示例代码")
