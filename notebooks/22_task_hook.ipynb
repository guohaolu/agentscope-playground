# %% [markdown]
# # 5.5 Agent - Agent Hooks
#
# - **对应文档**: [task_hook](https://doc.agentscope.io/tutorial/task_hook.html)
# - **本讲目标**: 掌握 reply/observe/print、_reasoning/_acting 等处的 hooks 用法。
# - **前置知识**: 18_task_agent。

# %%
# 在此按 doc 编写 Agent Hooks 示例
# 参考 https://doc.agentscope.io/tutorial/task_hook.html
print("请参考 task_hook 文档完成 Hooks 示例代码")
