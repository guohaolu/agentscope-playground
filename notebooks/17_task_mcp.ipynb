# %% [markdown]
# # 4.3 Tool - MCP
#
# - **对应文档**: [task_mcp](https://doc.agentscope.io/tutorial/task_mcp.html)
# - **本讲目标**: 掌握 Model Context Protocol (MCP) 与 AgentScope 的集成方式。
# - **前置知识**: 15_task_tool。

# %%
# 在此按 doc 编写 MCP 示例
# 参考 https://doc.agentscope.io/tutorial/task_mcp.html
print("请参考 task_mcp 文档完成 MCP 示例代码")
