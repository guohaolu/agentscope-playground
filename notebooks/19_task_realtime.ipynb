# %% [markdown]
# # 5.2 Agent - Realtime Agent
#
# - **对应文档**: [task_realtime](https://doc.agentscope.io/tutorial/task_realtime.html)
# - **本讲目标**: 理解实时交互、用户中断与 handle_interrupt 等。
# - **前置知识**: 18_task_agent。

# %%
# 在此按 doc 编写 Realtime Agent 示例
# 参考 https://doc.agentscope.io/tutorial/task_realtime.html
print("请参考 task_realtime 文档完成 Realtime Agent 示例代码")
