# %% [markdown]
# # 6.3 Features - Plan
#
# - **对应文档**: [task_plan](https://doc.agentscope.io/tutorial/task_plan.html)
# - **本讲目标**: 掌握 Plan/计划 notebook 与 ReActAgent 的 plan_notebook 集成。
# - **前置知识**: 02_react_agent。

# %%
# 在此按 doc 编写 Plan 示例
# 参考 https://doc.agentscope.io/tutorial/task_plan.html
print("请参考 task_plan 文档完成 Plan 示例代码")
