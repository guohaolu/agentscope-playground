# %% [markdown]
# # 4.2 Tool - Agent Skill
#
# - **对应文档**: [task_agent_skill](https://doc.agentscope.io/tutorial/task_agent_skill.html)
# - **本讲目标**: 理解将 Agent 能力封装为 Skill（可被其他 Agent 调用）的用法。
# - **前置知识**: 15_task_tool, 02_react_agent。

# %%
# 在此按 doc 编写 Agent Skill 示例
# 参考 https://doc.agentscope.io/tutorial/task_agent_skill.html
print("请参考 task_agent_skill 文档完成 Agent Skill 示例代码")
