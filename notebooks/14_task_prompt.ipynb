# %% [markdown]
# # 3.5 Model and Context - Prompt Formatter
#
# - **对应文档**: [task_prompt](https://doc.agentscope.io/tutorial/task_prompt.html)
# - **本讲目标**: 理解 Formatter 将 Message 转为 LLM API 格式、多身份与截断等。
# - **前置知识**: 03_message, 10_task_model。

# %% [markdown]
# ## 学习要点
#
# - Formatter 与 Model 的配套（如 DashScopeChatFormatter + DashScopeChatModel）。
# - Multi-agent formatter 在多身份场景下的用法。

# %%
# 在此按 doc 编写 Prompt Formatter 示例
# from agentscope.formatter import DashScopeChatFormatter
# 参考 https://doc.agentscope.io/tutorial/task_prompt.html
print("请参考 task_prompt 文档完成 Formatter 示例代码")
