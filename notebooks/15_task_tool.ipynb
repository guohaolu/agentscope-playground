# %% [markdown]
# # 4.1 Tool - 定义与注册
#
# - **对应文档**: [task_tool](https://doc.agentscope.io/tutorial/task_tool.html)
# - **本讲目标**: 掌握 Tool 的定义、Toolkit 注册、同步/异步与 streaming 工具。
# - **前置知识**: 02_react_agent。

# %% [markdown]
# ## 学习要点
#
# - 可调用对象作为 Tool：函数、方法、偏函数等。
# - Toolkit.register_tool_function、execute_python_code 等内置工具。

# %%
from agentscope.tool import Toolkit, execute_python_code

# 注册内置工具并查看
toolkit = Toolkit()
toolkit.register_tool_function(execute_python_code)
print("已注册 execute_python_code，可继续按 doc 添加自定义工具")
# 参考 https://doc.agentscope.io/tutorial/task_tool.html
