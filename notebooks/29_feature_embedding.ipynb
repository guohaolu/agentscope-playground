# %% [markdown]
# # 6.6 Features - Embedding
#
# - **对应文档**: [task_embedding](https://doc.agentscope.io/tutorial/task_embedding.html)
# - **本讲目标**: 掌握 Embedding 模型配置与在 RAG/检索中的用法。
# - **前置知识**: 10_task_model, 24_feature_rag（可选）。

# %%
# 在此按 doc 编写 Embedding 示例
# 参考 https://doc.agentscope.io/tutorial/task_embedding.html
print("请参考 task_embedding 文档完成 Embedding 示例代码")
